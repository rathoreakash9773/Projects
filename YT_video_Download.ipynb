# %%
pip install isodate
# Out:
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate) (1.16.0)
# Installing collected packages: isodate
# Successfully installed isodate-0.6.1

# %%
pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 989.9 kB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pytube import YouTube
import os
import csv
import pytube
import re

# Define the regex search function to extract video ID
def regex_search(pattern, text):
    match = re.search(pattern, text)
    return match.group(1) if match else None
# Path to the file containing YouTube video URLs


# Path to the file containing YouTube video URLs
file_path = '/content/youtube (2).csv'   # scrap csv

# Path to the folder where you want to save the downloaded videos
output_folder = '/content/drive/MyDrive/Akash_Ads_keyframes/Akash/new'
# Read video URLs from the file using 'latin-1' encoding
with open(file_path, 'r', encoding='latin-1') as file:
    video_urls = file.readlines()

# Remove whitespace characters such as '\n' from each URL
video_urls = [url.strip() for url in video_urls]

# Download videos
for url in video_urls:
    try:
        # Create a YouTube object
        yt = YouTube(url)

        # Get the highest resolution video stream
        video_stream = yt.streams.get_highest_resolution()

        # Download the video
        print(f"Downloading: {yt.title}...")
        video_stream.download(output_folder)
        print(f"Download complete for {yt.title}!\n")

    except Exception as e:
        print(f"Error downloading video from {url}: {e}\n")
# Out:
# Error downloading video from url: regex_search: could not find match for (?:v=|\/)([0-9A-Za-z_-]{11}).*
#
# Downloading: Fogg | Club | Malayalam | 30secs...
# Download complete for Fogg | Club | Malayalam | 30secs!
#
# Downloading: Fogg | Club | Bengali | 30secs...
# Download complete for Fogg | Club | Bengali | 30secs!
#
# Downloading: Fogg | Bus stop | Tamil | 35secs...
# Download complete for Fogg | Bus stop | Tamil | 35secs!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-473009a54779> in <cell line: 27>()
#      31
#      32         # Get the highest resolution video stream
# ---> 33         video_stream = yt.streams.get_highest_resolution()
#      34
#      35         # Download the video
#
# /usr/local/lib/python3.10/dist-packages/pytube/__main__.py in streams(self)
#     294         """
#     295         self.check_availability()
# --> 296         return StreamQuery(self.fmt_streams)
#     297
#     298     @property
#
# /usr/local/lib/python3.10/dist-packages/pytube/__main__.py in fmt_streams(self)
#     168         streams and initializes them.
#     169         """
# --> 170         self.check_availability()
#     171         if self._fmt_streams:
#     172             return self._fmt_streams
#
# /usr/local/lib/python3.10/dist-packages/pytube/__main__.py in check_availability(self)
#     208         otherwise does nothing.
#     209         """
# --> 210         status, messages = extract.playability_status(self.watch_html)
#     211
#     212         for reason in messages:
#
# /usr/local/lib/python3.10/dist-packages/pytube/extract.py in playability_status(watch_html)
#     104         Playability status and reason of the video.
#     105     """
# --> 106     player_response = initial_player_response(watch_html)
#     107     status_dict = player_response.get('playabilityStatus', {})
#     108     if 'liveStreamability' in status_dict:
#
# /usr/local/lib/python3.10/dist-packages/pytube/extract.py in initial_player_response(watch_html)
#     533     for pattern in patterns:
#     534         try:
# --> 535             return parse_for_object(watch_html, pattern)
#     536         except HTMLParseError:
#     537             pass
#
# /usr/local/lib/python3.10/dist-packages/pytube/parser.py in parse_for_object(html, preceding_regex)
#      55
#      56     start_index = result.end()
# ---> 57     return parse_for_object_from_startpoint(html, start_index)
#      58
#      59
#
# /usr/local/lib/python3.10/dist-packages/pytube/parser.py in parse_for_object_from_startpoint(html, start_point)
#     132         A dict created from parsing the object.
#     133     """
# --> 134     full_obj = find_object_from_startpoint(html, start_point)
#     135     try:
#     136         return json.loads(full_obj)
#
# /usr/local/lib/python3.10/dist-packages/pytube/parser.py in find_object_from_startpoint(html, start_point)
#     105         if curr_context in ['"', '/']:
#     106             # If there's a backslash in a string or regex expression, we skip a character
# --> 107             if curr_char == '\\':
#     108                 i += 2
#     109                 continue
#
# KeyboardInterrupt:

# %%
import pandas as pd
from googleapiclient.discovery import build
import isodate

# Set up your YouTube API credentials   youtube data api v3
# You need to create a project in the Google Cloud Console and enable the YouTube API
# Then, create API credentials and replace 'YOUR_API_KEY' with your actual API key
api_key = 'AIzaSyDIICOmmzCNZn3PUxuJ0Mj7Wxts9_YClno'   # Your API key
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# Replace the csv_file_path with the path to your CSV file containing YouTube video URLs
csv_file_path = r"/content/drive/MyDrive/Akash_Ads_keyframes/NYX_Keyframes/Milan yt/Mountain Dew/MountainDew_url.csv"   # Scrap csv
df_video_urls = pd.read_csv(csv_file_path, encoding='latin1')

video_urls = df_video_urls['video_url'].tolist()

video_data = []

for video_url in video_urls:
    try:
        print(f"Fetching data for video URL: {video_url}")

        # Extract video ID from the URL
        video_id = video_url.split("v=")[1]

        # Get video details from the YouTube API
        video_info = youtube.videos().list(part='snippet,contentDetails,statistics', id=video_id).execute()
        video_details = video_info['items'][0]

        # Convert duration to a more human-readable format
        duration_iso8601 = video_details['contentDetails']['duration']
        video_duration = isodate.parse_duration(duration_iso8601)

        video_data.append({
            'Video URL': video_url,
            'Video Title': video_details['snippet']['title'],
            'Channel Title': video_details['snippet']['channelTitle'],
            'Publish Time': video_details['snippet']['publishedAt'],
            'Views': video_details['statistics']['viewCount'],
            'Likes': video_details['statistics'].get('likeCount', 0),
            'Dislikes': video_details['statistics'].get('dislikeCount', 0),
            'Comments': video_details['statistics'].get('commentCount', 0),
            'Video Duration': str(video_duration),
            'Video Description': video_details['snippet'].get('description', ''),
        })

    except Exception as e:
        print(f"Error fetching data for video URL: {video_url}")
        print(f"Error details: {str(e)}")

# Create DataFrame only if video_data is not empty
if video_data:
    df_video_data = pd.DataFrame(video_data)
else:
    print("No video details available.")

# Save the final DataFrame to a CSV file
df_video_data.to_csv("Fogg_Final.csv", index=False)   # output csv meta data csv

# Display the final DataFrame
print(df_video_data)
# Out:
# Fetching data for video URL: https://www.youtube.com/watch?v=iSbvhOMtLV0
# Fetching data for video URL: https://www.youtube.com/watch?v=WL9TrAgnvx8
# Fetching data for video URL: https://www.youtube.com/watch?v=dNlrwnyAgBI
# Fetching data for video URL: https://www.youtube.com/watch?v=1WMXa__slM8
# Fetching data for video URL: https://www.youtube.com/watch?v=CYaORwhD-Eg
# Fetching data for video URL: https://www.youtube.com/watch?v=-yktHU8bJCE
# Fetching data for video URL: https://www.youtube.com/watch?v=K7yfpbjh3mc
# 2   2021-07-09T17:04:06Z    34048   572         0        0        0:01:24
# 3   2021-03-10T17:00:51Z    17230   181         0        0        0:00:23
# 4   2021-01-26T13:00:01Z  1055115  1484         0      245        0:00:16
# ..                   ...      ...   ...       ...      ...            ...
# 63  2019-01-15T14:54:46Z     1183    42         0        4        0:01:55
# 64  2018-08-18T16:47:16Z    17958   208         0       28        0:00:17
# 65  2018-04-07T16:50:41Z     7896   129         0       13        0:01:49
# 66  2018-02-26T22:00:37Z     1885    12         0        0        0:00:42
# 67  2018-02-23T19:00:55Z     6975    98         0        6        0:01:01
#
#                                     Video Description
# 0   Grab a crisp, refreshing MTN DEW. Trust us, yo...
# 1   MTN DEW pro skateboarder Sean Malto and friend...
# 2   ATTENTION!! Have you been ghosted? Are you fee...
# 3   Christian Harwell shared how his team of under...
# 4   Something life changing is coming to Super Bow...
# ..                                                ...
# 63  Watch as Mountain Dew pro snowboarders Danny D...
# 64  DEW sling, cooler of ice cold DEW, Chase Ellio...
# 65  Mountain Dew pro skateboarder Theotis Beasley ...
# 66  Take pointers people! Kevin Hart explained som...
# 67  Pro Tip #2: DO stay in your seat.This isn’t mu...
#
# [68 rows x 10 columns]

# %%
pip install --upgrade moviepy
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)

# %%
import os
from moviepy.editor import VideoFileClip
import csv

def get_video_metadata(file_path, print_infos=True):
    try:
        clip = VideoFileClip(file_path)
        file_name = os.path.basename(file_path)
        file_name_without_extension = os.path.splitext(file_name)[0]  # Remove file extension
        return {
            'file_name': file_name_without_extension,
            'duration': clip.duration,
            'resolution': clip.size,
            # Add more metadata fields as needed
        }
    except Exception as e:
        if print_infos:
            print(f"Error processing {file_path}: {e}")
        return None

def create_csv(folder_path, csv_path):
    with open(csv_path, 'w', newline='') as csvfile:
        fieldnames = ['file_name', 'duration', 'resolution']
        # Add more fieldnames as needed
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for file_name in os.listdir(folder_path):
            if file_name.endswith('.mp4'):
                file_path = os.path.join(folder_path, file_name)
                video_metadata = get_video_metadata(file_path)
                if video_metadata is not None:  # Check if video_metadata is not None
                    writer.writerow(video_metadata)

folder_path = '/content/drive/MyDrive/Akash_Ads_keyframes/NYX_Keyframes/Milan yt/Mountain Dew/Videos'   # output folder
csv_path = '/content/Fogg_metadata1.csv'  # Use absolute path

create_csv(folder_path, csv_path)
